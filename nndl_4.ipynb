# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

X = np.random.rand(1000, 20)
y = np.random.randint(0, 2,1000)

print("Input data shape:", X.shape)
print("Output data shape:", y.shape)
# Out:
# Input data shape: (1000, 20)
# Output data shape: (1000,)

# %%
model = keras.Sequential([
    layers.Input(shape=(20,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,457 (13.50 KB)
#  Trainable params: 3,457 (13.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X, y,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4944 - loss: 0.6966 - val_accuracy: 0.4500 - val_loss: 0.7044
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5351 - loss: 0.6894 - val_accuracy: 0.4500 - val_loss: 0.6983
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5240 - loss: 0.6892 - val_accuracy: 0.4800 - val_loss: 0.6980
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5395 - loss: 0.6885 - val_accuracy: 0.4700 - val_loss: 0.7002
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5621 - loss: 0.6829 - val_accuracy: 0.4700 - val_loss: 0.7008
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5964 - loss: 0.6782 - val_accuracy: 0.4800 - val_loss: 0.7004
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5913 - loss: 0.6780 - val_accuracy: 0.4950 - val_loss: 0.7012
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5778 - loss: 0.6789 - val_accuracy: 0.4800 - val_loss: 0.7048
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5830 - loss: 0.6724 - val_accuracy: 0.4950 - val_loss: 0.6928
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6079 - loss: 0.6704 - val_accuracy: 0.4900 - val_loss: 0.7042
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5931 - loss: 0.6733 - val_accuracy: 0.5100 - val_loss: 0.7018
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6126 - loss: 0.6685 - val_accuracy: 0.5150 - val_loss: 0.7060
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6725 - val_accuracy: 0.4900 - val_loss: 0.7004
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6187 - loss: 0.6639 - val_accuracy: 0.5050 - val_loss: 0.7037
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6390 - loss: 0.6656 - val_accuracy: 0.5050 - val_loss: 0.7052
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6364 - loss: 0.6596 - val_accuracy: 0.4800 - val_loss: 0.6969
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6373 - loss: 0.6569 - val_accuracy: 0.5100 - val_loss: 0.7017
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5897 - loss: 0.6618 - val_accuracy: 0.4950 - val_loss: 0.7125
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6527 - loss: 0.6453 - val_accuracy: 0.5050 - val_loss: 0.7009
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6417 - loss: 0.6559 - val_accuracy: 0.5100 - val_loss: 0.7017

# %%
loss, accuracy = model.evaluate(X, y)
print("Accuracy:",accuracy)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6726 - loss: 0.6487
# Accuracy: 0.6430000066757202

# %%
predictions = model.predict(X[:5])
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.6385497 ]
#  [0.37042886]
#  [0.48855394]
#  [0.43203035]
#  [0.5548768 ]]

# %%
new_data = np.random.rand(5, 20)
predictions = model.predict(new_data)

print("\nNew data for prediction:\n", new_data)
print("\nPredictions (probabilities):\n", predictions)
binary_predictions = (predictions > 0.5).astype(int)
print("\nBinary predictions:\n", binary_predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
#
# New data for prediction:
#  [[0.3796286  0.27223669 0.86914037 0.2584458  0.23762899 0.90436214
#   0.04631729 0.26579817 0.63010474 0.4155123  0.54686128 0.22631152
#   0.74322392 0.53063895 0.92728167 0.8237748  0.45864216 0.07721337
#   0.87221179 0.30834456]
#  [0.86368893 0.80080385 0.61741891 0.28901367 0.34096691 0.93201109
#   0.35818382 0.43217303 0.12020567 0.45600655 0.00431286 0.14974833
#   0.9057134  0.03837625 0.14258349 0.57015752 0.63433228 0.17819864
#   0.42993239 0.98191965]
#  [0.13481199 0.68087559 0.22375754 0.15807767 0.62706242 0.18961534
#   0.79088859 0.18593355 0.03172189 0.4148373  0.59359236 0.87073901
#   0.35393483 0.59568924 0.55588255 0.81093334 0.39894301 0.17052968
#   0.92340522 0.92241224]
#  [0.03044446 0.02688349 0.75171452 0.7146378  0.04465684 0.65191931
#   0.34412961 0.15040727 0.00963618 0.06356929 0.07323515 0.39168799
#   0.2397945  0.1250683  0.12700985 0.47156876 0.13270932 0.81755482
#   0.60488533 0.7216386 ]
#  [0.26255263 0.07854194 0.73495694 0.14478475 0.52752299 0.2557416
#   0.00476203 0.61492862 0.44347331 0.54786929 0.77182778 0.05852986
#   0.93586513 0.71303245 0.18095486 0.44015166 0.16305284 0.58402418
#   0.06231429 0.42682218]]
#
# Predictions (probabilities):
#  [[0.55152076]
#  [0.5492963 ]
#  [0.41079634]
#  [0.44269517]
#  [0.64415574]]
#
# Binary predictions:
#  [[1]
#  [1]
#  [0]
#  [0]
#  [1]]
